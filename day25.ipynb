# %%
from utils import read_lines
from collections import defaultdict
from itertools import combinations

def parse_program(s):
    return [int(x) for x in s.split(',')]

def parse_code(num):
    if num == 99:
        return num, [0]
    else:
        digits = []
        while num > 0:
            digits.append(num % 10)
            num //=10
        digits += [0] * (5-len(digits))
        opcode = digits[0]
        param_modes = digits[2:]
        return opcode, param_modes

def run(program, inputs):
    i = 0
    outputs = []
    extend_memory = defaultdict(int)
    relative_base = 0
    input_pos = 0
    commands_generator = generate_combinations()
    def read_memory(addr):
        if addr < len(program):
            return program[addr]
        else:
            return extend_memory[addr]
        
    def write_memory(idx, value, mode):
        addr = program[idx]
        if mode == 2:
            addr = relative_base + addr
        if addr < len(program):
            program[addr] = value
        else:
            extend_memory[addr] = value
    
    def get_oprand(idx, mode):
        if mode == 1:
            return program[idx]
        if mode == 2:
            addr = relative_base + program[idx]
        else:
            addr = program[idx]
        return read_memory(addr)

    while i < len(program):
        opcode, param_modes = parse_code(program[i])
        if opcode in (1, 2, 5, 6, 7, 8):
            oprand1 = get_oprand(i+1, param_modes[0])
            oprand2 = get_oprand(i+2, param_modes[1])
    
            if opcode == 1:
                write_memory(i+3, oprand1 + oprand2, param_modes[2])
                i+=4
            elif opcode == 2:
                write_memory(i+3, oprand1 * oprand2, param_modes[2])
                i+=4
            elif opcode == 5:
                if oprand1 != 0:
                    i = oprand2
                else:
                    i += 3
            elif opcode == 6:
                if oprand1 == 0:
                    i = oprand2
                else:
                    i += 3
            elif opcode == 7:
                write_memory(i+3, 1 if oprand1 < oprand2 else 0, param_modes[2])
                i+=4
            elif opcode == 8:
                write_memory(i+3, 1 if oprand1 == oprand2 else 0, param_modes[2])
                i+=4
        elif opcode ==3 :
            if not inputs:
                print_outputs(outputs)
                outputs = []
                commands = next(commands_generator)
                print(f'>>{commands}')
                
                inputs = encode_commands(commands)
                input_pos = 0

            v = inputs[input_pos]
            input_pos += 1
            if input_pos == len(inputs):
                inputs = []
            write_memory(i+1, v, param_modes[0])
            i += 2

        elif opcode == 4:
            oprand1 = get_oprand(i+1, param_modes[0])
            i += 2
            outputs.append(oprand1)
        elif opcode == 9:
            oprand1 = get_oprand(i+1, param_modes[0])
            relative_base += oprand1
            i+=2
        elif program[i] == 99:
            return outputs
        else:
            raise ValueError(f'illegal code {i} {program[i]}')

def print_outputs(outputs):
    print(''.join(chr(c) for c in outputs))

def generate_combinations():
    all_items = """jam
loom
mug
spool of cat6
prime number
food ration
fuel cell
manifold"""
    all_items = all_items.split('\n')
    cur_items = all_items[:]
    for r in range(len(all_items), 0, -1):
        for comb in combinations(all_items, r):
            commands = []
            for item in cur_items:
                if item not in comb:
                    commands.append(f'drop {item}')
            for item in comb:
                if item not in cur_items:
                    commands.append(f'take {item}')
            cur_items = list(comb)
            commands.append('north')
            yield commands


def part1(input_file):
    s = read_lines(input_file)[0]
    program = parse_program(s)
    initial_commands = [
        'east',
        'take food ration',
        'south',
        'take prime number',
        'north',
        'east',
        'take manifold',
        'east',
        'east',
        'take jam',
        'west',
        'north',
        'east',
        'take spool of cat6',
        'west',
        'north',
        'take fuel cell',
        'south',
        'south',
        'west',
        'west',
        'west',
        'north',
        'north',
        'west',
        'take mug',
        'east',
        'north',
        'east',
        'east',
        'take loom',
        'west',
        'west',
        'south',
        'south',
        'west',
        'north',
        'west',
        'inv'
    ]
    outputs = run(program, encode_commands(initial_commands))
    print_outputs(outputs)

def encode(func):
    ans = [ord(c) for c in func]
    ans.append(10)
    return ans

def encode_commands(cmds):
    return [c for cmd in cmds for c in encode(cmd)]

# %%
part1('inputs/day25.txt')
# Out:
# == Hull Breach ==
# You got in through a hole in the floor here. To keep your ship from also freezing, the hole has been sealed.
#
# Doors here lead:
# - north
# - east
#
# Command?
#
#
#
# == Hot Chocolate Fountain ==
# Somehow, it's still working.
#
# Doors here lead:
# - east
# - south
# - west
#
# Items here:
# - food ration
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Science Lab ==
# You see evidence here of prototype polymer design work.
#
# Doors here lead:
# - north
#
# Items here:
# - prime number
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Hot Chocolate Fountain ==
# Somehow, it's still working.
#
# Doors here lead:
# - east
# - south
# - west
#
# Command?
#
#
#
# == Gift Wrapping Center ==
# How else do you wrap presents on the go?
#
# Doors here lead:
# - east
# - south
# - west
#
# Items here:
# - manifold
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Navigation ==
# Status: Stranded. Please supply measurements from fifty stars to recalibrate.
#
# Doors here lead:
# - north
# - east
# - west
#
# Command?
#
#
#
# == Kitchen ==
# Everything's freeze-dried.
#
# Doors here lead:
# - west
#
# Items here:
# - jam
#
# Command?
#
# You take the jam.
#
# Command?
#
#
#
# == Navigation ==
# Status: Stranded. Please supply measurements from fifty stars to recalibrate.
#
# Doors here lead:
# - north
# - east
# - west
#
# Command?
#
#
#
# == Holodeck ==
# Someone seems to have left it on the Giant Grid setting.
#
# Doors here lead:
# - north
# - east
# - south
#
# Command?
#
#
#
# == Warp Drive Maintenance ==
# It appears to be working normally.
#
# Doors here lead:
# - west
#
# Items here:
# - spool of cat6
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
#
#
# == Holodeck ==
# Someone seems to have left it on the Giant Grid setting.
#
# Doors here lead:
# - north
# - east
# - south
#
# Command?
#
#
#
# == Passages ==
# They're a little twisty and starting to look all alike.
#
# Doors here lead:
# - south
#
# Items here:
# - fuel cell
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Holodeck ==
# Someone seems to have left it on the Giant Grid setting.
#
# Doors here lead:
# - north
# - east
# - south
#
# Command?
#
#
#
# == Navigation ==
# Status: Stranded. Please supply measurements from fifty stars to recalibrate.
#
# Doors here lead:
# - north
# - east
# - west
#
# Command?
#
#
#
# == Gift Wrapping Center ==
# How else do you wrap presents on the go?
#
# Doors here lead:
# - east
# - south
# - west
#
# Command?
#
#
#
# == Hot Chocolate Fountain ==
# Somehow, it's still working.
#
# Doors here lead:
# - east
# - south
# - west
#
# Command?
#
#
#
# == Hull Breach ==
# You got in through a hole in the floor here. To keep your ship from also freezing, the hole has been sealed.
#
# Doors here lead:
# - north
# - east
#
# Command?
#
#
#
# == Hallway ==
# This area has been optimized for something; you're just not quite sure what.
#
# Doors here lead:
# - north
# - south
# - west
#
# Items here:
# - photons
#
# Command?
#
#
#
# == Arcade ==
# None of the cabinets seem to have power.
#
# Doors here lead:
# - north
# - south
# - west
#
# Command?
#
#
#
# == Observatory ==
# There are a few telescopes; they're all bolted down, though.
#
# Doors here lead:
# - east
#
# Items here:
# - mug
#
# Command?
#
# You take the mug.
#
# Command?
#
#
#
# == Arcade ==
# None of the cabinets seem to have power.
#
# Doors here lead:
# - north
# - south
# - west
#
# Command?
#
#
#
# == Crew Quarters ==
# The beds are all too small for you.
#
# Doors here lead:
# - east
# - south
#
# Items here:
# - infinite loop
#
# Command?
#
#
#
# == Corridor ==
# The metal walls and the metal floor are slightly different colors. Or are they?
#
# Doors here lead:
# - east
# - west
#
# Items here:
# - molten lava
#
# Command?
#
#
#
# == Storage ==
# The boxes just contain more boxes.  Recursively.
#
# Doors here lead:
# - west
#
# Items here:
# - loom
#
# Command?
#
# You take the loom.
#
# Command?
#
#
#
# == Corridor ==
# The metal walls and the metal floor are slightly different colors. Or are they?
#
# Doors here lead:
# - east
# - west
#
# Items here:
# - molten lava
#
# Command?
#
#
#
# == Crew Quarters ==
# The beds are all too small for you.
#
# Doors here lead:
# - east
# - south
#
# Items here:
# - infinite loop
#
# Command?
#
#
#
# == Arcade ==
# None of the cabinets seem to have power.
#
# Doors here lead:
# - north
# - south
# - west
#
# Command?
#
#
#
# == Hallway ==
# This area has been optimized for something; you're just not quite sure what.
#
# Doors here lead:
# - north
# - south
# - west
#
# Items here:
# - photons
#
# Command?
#
#
#
# == Engineering ==
# You see a whiteboard with plans for Springdroid v2.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - escape pod
#
# Command?
#
#
#
# == Stables ==
# Reindeer-sized. They're all empty.
#
# Doors here lead:
# - south
# - west
#
# Items here:
# - giant electromagnet
#
# Command?
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Command?
#
# Items in your inventory:
# - jam
# - loom
# - mug
# - spool of cat6
# - prime number
# - food ration
# - fuel cell
# - manifold
#
# Command?
#
# >>['north']
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Command?
#
# >>['drop manifold', 'north']
#
# You drop the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - food ration
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - prime number
#
# Command?
#
# >>['drop spool of cat6', 'take prime number', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
#
# Command?
#
# >>['drop mug', 'take spool of cat6', 'north']
#
# You drop the mug.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
#
# Command?
#
# >>['drop loom', 'take mug', 'north']
#
# You drop the loom.
#
# Command?
#
# You take the mug.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
#
# Command?
#
# >>['drop jam', 'take loom', 'north']
#
# You drop the jam.
#
# Command?
#
# You take the loom.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
#
# Command?
#
# >>['drop fuel cell', 'drop manifold', 'take jam', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the jam.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop prime number', 'drop manifold', 'take food ration', 'take fuel cell', 'north']
#
# You drop the prime number.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - prime number
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - prime number
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - prime number
# - food ration
#
# Command?
#
# >>['drop spool of cat6', 'drop manifold', 'take prime number', 'take food ration', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - food ration
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - prime number
#
# Command?
#
# >>['drop mug', 'drop manifold', 'take spool of cat6', 'take prime number', 'north']
#
# You drop the mug.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - food ration
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - prime number
#
# Command?
#
# >>['drop spool of cat6', 'take prime number', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - spool of cat6
#
# Command?
#
# >>['drop loom', 'drop manifold', 'take mug', 'take spool of cat6', 'north']
#
# You drop the loom.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the mug.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - food ration
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - prime number
#
# Command?
#
# >>['drop spool of cat6', 'take prime number', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - spool of cat6
#
# Command?
#
# >>['drop mug', 'take spool of cat6', 'north']
#
# You drop the mug.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - mug
#
# Command?
#
# >>['drop jam', 'drop manifold', 'take loom', 'take mug', 'north']
#
# You drop the jam.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the loom.
#
# Command?
#
# You take the mug.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - food ration
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - prime number
#
# Command?
#
# >>['drop spool of cat6', 'take prime number', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - spool of cat6
#
# Command?
#
# >>['drop mug', 'take spool of cat6', 'north']
#
# You drop the mug.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
#
# Command?
#
# >>['drop loom', 'take mug', 'north']
#
# You drop the loom.
#
# Command?
#
# You take the mug.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - loom
#
# Command?
#
# >>['drop food ration', 'drop fuel cell', 'drop manifold', 'take jam', 'take loom', 'north']
#
# You drop the food ration.
#
# Command?
#
# You drop the fuel cell.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the jam.
#
# Command?
#
# You take the loom.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - food ration
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - prime number
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - prime number
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - prime number
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop spool of cat6', 'drop manifold', 'take prime number', 'take food ration', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop prime number', 'drop manifold', 'take food ration', 'take fuel cell', 'north']
#
# You drop the prime number.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - prime number
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - prime number
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - spool of cat6
# - prime number
# - food ration
#
# Command?
#
# >>['drop mug', 'drop fuel cell', 'drop manifold', 'take spool of cat6', 'take prime number', 'take food ration', 'north']
#
# You drop the mug.
#
# Command?
#
# You drop the fuel cell.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop prime number', 'drop manifold', 'take food ration', 'take fuel cell', 'north']
#
# You drop the prime number.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - prime number
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - prime number
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - prime number
# - food ration
#
# Command?
#
# >>['drop spool of cat6', 'drop manifold', 'take prime number', 'take food ration', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - spool of cat6
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - spool of cat6
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - spool of cat6
# - food ration
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - mug
# - spool of cat6
# - prime number
#
# Command?
#
# >>['drop loom', 'drop fuel cell', 'drop manifold', 'take mug', 'take spool of cat6', 'take prime number', 'north']
#
# You drop the loom.
#
# Command?
#
# You drop the fuel cell.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the mug.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop prime number', 'drop manifold', 'take food ration', 'take fuel cell', 'north']
#
# You drop the prime number.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - prime number
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - prime number
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - prime number
# - food ration
#
# Command?
#
# >>['drop spool of cat6', 'drop manifold', 'take prime number', 'take food ration', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - spool of cat6
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - spool of cat6
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - spool of cat6
# - food ration
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - spool of cat6
# - prime number
#
# Command?
#
# >>['drop mug', 'drop manifold', 'take spool of cat6', 'take prime number', 'north']
#
# You drop the mug.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - mug
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - mug
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - mug
# - food ration
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - mug
# - prime number
#
# Command?
#
# >>['drop spool of cat6', 'take prime number', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - mug
# - spool of cat6
#
# Command?
#
# >>['drop jam', 'drop fuel cell', 'drop manifold', 'take loom', 'take mug', 'take spool of cat6', 'north']
#
# You drop the jam.
#
# Command?
#
# You drop the fuel cell.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the loom.
#
# Command?
#
# You take the mug.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop prime number', 'drop manifold', 'take food ration', 'take fuel cell', 'north']
#
# You drop the prime number.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - prime number
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - prime number
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - prime number
# - food ration
#
# Command?
#
# >>['drop spool of cat6', 'drop manifold', 'take prime number', 'take food ration', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - spool of cat6
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# ...
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - loom
# - mug
# - spool of cat6
# - prime number
#
# Command?
#
# >>['drop jam', 'drop food ration', 'drop fuel cell', 'drop manifold', 'take loom', 'take mug', 'take spool of cat6', 'take prime number', 'north']
#
# You drop the jam.
#
# Command?
#
# You drop the food ration.
#
# Command?
#
# You drop the fuel cell.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the loom.
#
# Command?
#
# You take the mug.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - food ration
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - prime number
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - prime number
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - prime number
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop spool of cat6', 'drop manifold', 'take prime number', 'take food ration', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - spool of cat6
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - spool of cat6
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - spool of cat6
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop prime number', 'drop manifold', 'take food ration', 'take fuel cell', 'north']
#
# You drop the prime number.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - spool of cat6
# - prime number
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - spool of cat6
# - prime number
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - spool of cat6
# - prime number
# - food ration
#
# Command?
#
# >>['drop mug', 'drop fuel cell', 'drop manifold', 'take spool of cat6', 'take prime number', 'take food ration', 'north']
#
# You drop the mug.
#
# Command?
#
# You drop the fuel cell.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop prime number', 'drop manifold', 'take food ration', 'take fuel cell', 'north']
#
# You drop the prime number.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - prime number
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - prime number
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - prime number
# - food ration
#
# Command?
#
# >>['drop spool of cat6', 'drop manifold', 'take prime number', 'take food ration', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - spool of cat6
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - spool of cat6
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - spool of cat6
# - food ration
#
# Command?
#
# >>['drop prime number', 'take food ration', 'north']
#
# You drop the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are heavier than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - mug
# - spool of cat6
# - prime number
#
# Command?
#
# >>['drop loom', 'drop fuel cell', 'drop manifold', 'take mug', 'take spool of cat6', 'take prime number', 'north']
#
# You drop the loom.
#
# Command?
#
# You drop the fuel cell.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the mug.
#
# Command?
#
# You take the spool of cat6.
#
# Command?
#
# You take the prime number.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - loom
# - fuel cell
# - manifold
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - loom
# - food ration
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - loom
# - food ration
# - fuel cell
#
# Command?
#
# >>['drop prime number', 'drop manifold', 'take food ration', 'take fuel cell', 'north']
#
# You drop the prime number.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - loom
# - prime number
# - manifold
#
# Command?
#
# >>['drop fuel cell', 'take manifold', 'north']
#
# You drop the fuel cell.
#
# Command?
#
# You take the manifold.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - loom
# - prime number
# - fuel cell
#
# Command?
#
# >>['drop food ration', 'take fuel cell', 'north']
#
# You drop the food ration.
#
# Command?
#
# You take the fuel cell.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Alert! Droids on this ship are lighter than the detected value!" and you are ejected back to the checkpoint.
#
#
#
# == Security Checkpoint ==
# In the next room, a pressure-sensitive floor will verify your identity.
#
# Doors here lead:
# - north
# - east
#
# Items here:
# - jam
# - loom
# - prime number
# - food ration
#
# Command?
#
# >>['drop spool of cat6', 'drop manifold', 'take prime number', 'take food ration', 'north']
#
# You drop the spool of cat6.
#
# Command?
#
# You drop the manifold.
#
# Command?
#
# You take the prime number.
#
# Command?
#
# You take the food ration.
#
# Command?
#
#
#
# == Pressure-Sensitive Floor ==
# Analyzing...
#
# Doors here lead:
# - south
#
# A loud, robotic voice says "Analysis complete! You may proceed." and you enter the cockpit.
# Santa notices your small droid, looks puzzled for a moment, realizes what has happened, and radios your ship directly.
# "Oh, hello! You should be able to get in by typing 537002052 on the keypad at the main airlock."
